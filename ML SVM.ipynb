# %% [markdown]
# # SVM Support Vector Machine

# %%
# Imports
import warnings
warnings.simplefilter('ignore')

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC

# %%
# Read the csv file into a pandas DataFrame
exoplanet_numeric = pd.read_csv('exoplanet_numeric.csv')
exoplanet_numeric.head()
# Out:
#    koi_score  koi_period  koi_time0bk  koi_impact  koi_duration  koi_depth  \
# 0      1.000    9.488036   170.538750       0.146       2.95750      615.8
# 1      0.969   54.418383   162.513840       0.586       4.50700      874.8
# 2      0.000   19.899140   175.850252       0.969       1.78220    10829.0
# 3      0.000    1.736952   170.307565       1.276       2.40641     8079.2
# 4      1.000    2.525592   171.595550       0.701       1.65450      603.3
#
#    koi_prad  koi_teq  koi_insol  koi_steff  koi_slogg  koi_srad         ra  \
# 0      2.26    793.0      93.59     5455.0      4.467     0.927  291.93423
# 1      2.83    443.0       9.11     5455.0      4.467     0.927  291.93423
# 2     14.60    638.0      39.30     5853.0      4.544     0.868  297.00482
# 3     33.46   1395.0     891.96     5805.0      4.564     0.791  285.53461
# 4      2.75   1406.0     926.16     6031.0      4.438     1.046  288.75488
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# ...

# %%
target = exoplanet_numeric['koi_score']

# %%
data = exoplanet_numeric.drop('koi_score', axis=1)
feature_names = data.columns
data.head()
# Out:
#    koi_period  koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  \
# 0    9.488036   170.538750       0.146       2.95750      615.8      2.26
# 1   54.418383   162.513840       0.586       4.50700      874.8      2.83
# 2   19.899140   175.850252       0.969       1.78220    10829.0     14.60
# 3    1.736952   170.307565       1.276       2.40641     8079.2     33.46
# 4    2.525592   171.595550       0.701       1.65450      603.3      2.75
#
#    koi_teq  koi_insol  koi_steff  koi_slogg  koi_srad         ra        dec  \
# 0    793.0      93.59     5455.0      4.467     0.927  291.93423  48.141651
# 1    443.0       9.11     5455.0      4.467     0.927  291.93423  48.141651
# 2    638.0      39.30     5853.0      4.544     0.868  297.00482  48.134129
# 3   1395.0     891.96     5805.0      4.564     0.791  285.53461  48.285210
# 4   1406.0     926.16     6031.0      4.438     1.046  288.75488  48.226200
#
#    koi_kepmag
# 0      15.347
# 1      15.347
# 2      15.436
# ...

# %%
# Separate train and test data
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
# Use MinMaxScalar
X_minmax = MinMaxScaler().fit(X_train)
y_minmax = MinMaxScaler().fit(y_train.reshape(-1, 1))

X_train_minmax = X_minmax.transform(X_train)
X_test_minmax = X_minmax.transform(X_test)
y_train_minmax = y_minmax.transform(y_train)
y_test_minmax = y_minmax.transform(y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-fdbd2d1f8a5e> in <module>
#       1 # Use MinMaxScalar
#       2 X_minmax = MinMaxScaler().fit(X_train)
# ----> 3 y_minmax = MinMaxScaler().fit(y_train.reshape(-1, 1))
#       4
#       5 X_train_minmax = X_minmax.transform(X_train)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %%
# Use SVC model - linear
model = SVC(kernel='linear')
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-186795884151> in <module>
#       1 # Use SVC model - linear
#       2 model = SVC(kernel='linear')
# ----> 3 model.fit(X_train, y_train)
#
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     148                          order='C', accept_sparse='csr',
#     149                          accept_large_sparse=False)
# --> 150         y = self._validate_targets(y)
#     151
#     152         sample_weight = np.asarray([]
#
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py in _validate_targets(self, y)
#     517     def _validate_targets(self, y):
#     518         y_ = column_or_1d(y, warn=True)
# --> 519         check_classification_targets(y)
#     520         cls, y = np.unique(y_, return_inverse=True)
# ...
