# %%
# Imports
import warnings
warnings.simplefilter('ignore')

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame
exoplanet_data = pd.read_csv('cumulative.csv')
exoplanet_data.head()
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  ...  \
# 0      1.000              0              0              0  ...
# 1      0.969              0              0              0  ...
# 2      0.000              0              1              0  ...
# 3      0.000              0              1              0  ...
# 4      1.000              0              0              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# ...

# %%
# Take out some columns
exoplanet_reduced1 = exoplanet_data.drop(['rowid', 'kepid','kepoi_name', 'koi_pdisposition','kepler_name', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co', 'koi_steff_err2', 'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad_err1', 'koi_srad_err2',], axis=1)
exoplanet_reduced1.head()
# Out:
#   koi_disposition  koi_score  koi_fpflag_ec  koi_period  koi_period_err1  \
# 0       CONFIRMED      1.000              0    9.488036     2.775000e-05
# 1       CONFIRMED      0.969              0   54.418383     2.479000e-04
# 2  FALSE POSITIVE      0.000              0   19.899140     1.494000e-05
# 3  FALSE POSITIVE      0.000              0    1.736952     2.630000e-07
# 4       CONFIRMED      1.000              0    2.525592     3.761000e-06
#
#    koi_period_err2  koi_time0bk  koi_time0bk_err1  koi_time0bk_err2  \
# 0    -2.775000e-05   170.538750          0.002160         -0.002160
# 1    -2.479000e-04   162.513840          0.003520         -0.003520
# 2    -1.494000e-05   175.850252          0.000581         -0.000581
# 3    -2.630000e-07   170.307565          0.000115         -0.000115
# 4    -3.761000e-06   171.595550          0.001130         -0.001130
#
#    koi_impact  ...  koi_model_snr  koi_tce_plnt_num  koi_tce_delivname  \
# ...

# %%
# Take out more columns
exoplanet_reduced2 = exoplanet_reduced1.drop(['koi_fpflag_ec', 'koi_period_err1', 'koi_period_err2','koi_teq_err1', 'koi_teq_err2', 'koi_insol_err1', 'koi_insol_err2', 'koi_tce_plnt_num', 'koi_tce_delivname', 'koi_steff_err1'], axis=1)
exoplanet_reduced2.head()
# Out:
#   koi_disposition  koi_score  koi_period  koi_time0bk  koi_time0bk_err1  \
# 0       CONFIRMED      1.000    9.488036   170.538750          0.002160
# 1       CONFIRMED      0.969   54.418383   162.513840          0.003520
# 2  FALSE POSITIVE      0.000   19.899140   175.850252          0.000581
# 3  FALSE POSITIVE      0.000    1.736952   170.307565          0.000115
# 4       CONFIRMED      1.000    2.525592   171.595550          0.001130
#
#    koi_time0bk_err2  koi_impact  koi_impact_err1  koi_impact_err2  \
# 0         -0.002160       0.146            0.318           -0.146
# 1         -0.003520       0.586            0.059           -0.443
# 2         -0.000581       0.969            5.126           -0.077
# 3         -0.000115       1.276            0.115           -0.092
# 4         -0.001130       0.701            0.235           -0.478
#
#    koi_duration  ...  koi_prad_err2  koi_teq  koi_insol  koi_model_snr  \
# ...

# %%
# Take out final columns
exoplanet_reduced3 = exoplanet_reduced2.drop(['koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact_err1', 'koi_impact_err2', 'koi_duration_err1', 'koi_duration_err2', 'koi_depth_err1', 'koi_depth_err2','koi_prad_err1', 'koi_prad_err2', 'koi_model_snr'], axis=1)
exoplanet_reduced3.head()
# Out:
#   koi_disposition  koi_score  koi_period  koi_time0bk  koi_impact  \
# 0       CONFIRMED      1.000    9.488036   170.538750       0.146
# 1       CONFIRMED      0.969   54.418383   162.513840       0.586
# 2  FALSE POSITIVE      0.000   19.899140   175.850252       0.969
# 3  FALSE POSITIVE      0.000    1.736952   170.307565       1.276
# 4       CONFIRMED      1.000    2.525592   171.595550       0.701
#
#    koi_duration  koi_depth  koi_prad  koi_teq  koi_insol  koi_steff  \
# 0       2.95750      615.8      2.26    793.0      93.59     5455.0
# 1       4.50700      874.8      2.83    443.0       9.11     5455.0
# 2       1.78220    10829.0     14.60    638.0      39.30     5853.0
# 3       2.40641     8079.2     33.46   1395.0     891.96     5805.0
# 4       1.65450      603.3      2.75   1406.0     926.16     6031.0
#
#    koi_slogg  koi_srad         ra        dec  koi_kepmag
# 0      4.467     0.927  291.93423  48.141651      15.347
# ...

# %%
# Exported this dataframe to be used with other models, but it contains NaN values

# Now commented out so it doesn't continue to export it
# exoplanet_reduced3.to_csv('exoplanet_reduced.csv', index=False)

# %%
# Drop rows with NaN values
exoplanet_complete = exoplanet_reduced3.dropna()
exoplanet_complete.head()
# Out:
#   koi_disposition  koi_score  koi_period  koi_time0bk  koi_impact  \
# 0       CONFIRMED      1.000    9.488036   170.538750       0.146
# 1       CONFIRMED      0.969   54.418383   162.513840       0.586
# 2  FALSE POSITIVE      0.000   19.899140   175.850252       0.969
# 3  FALSE POSITIVE      0.000    1.736952   170.307565       1.276
# 4       CONFIRMED      1.000    2.525592   171.595550       0.701
#
#    koi_duration  koi_depth  koi_prad  koi_teq  koi_insol  koi_steff  \
# 0       2.95750      615.8      2.26    793.0      93.59     5455.0
# 1       4.50700      874.8      2.83    443.0       9.11     5455.0
# 2       1.78220    10829.0     14.60    638.0      39.30     5853.0
# 3       2.40641     8079.2     33.46   1395.0     891.96     5805.0
# 4       1.65450      603.3      2.75   1406.0     926.16     6031.0
#
#    koi_slogg  koi_srad         ra        dec  koi_kepmag
# 0      4.467     0.927  291.93423  48.141651      15.347
# ...

# %%
# Exported this dataframe to be used with other models

# Now commented out so it doesn't continue to export it
# exoplanet_complete.to_csv('exoplanet_complete.csv', index=False)

# %%
# Binary encode the koi_disposition column in case of need later
exoplanet_binary_encoded = pd.get_dummies(exoplanet_complete, columns=['koi_disposition'])
exoplanet_binary_encoded.head()
# Out:
#    koi_score  koi_period  koi_time0bk  koi_impact  koi_duration  koi_depth  \
# 0      1.000    9.488036   170.538750       0.146       2.95750      615.8
# 1      0.969   54.418383   162.513840       0.586       4.50700      874.8
# 2      0.000   19.899140   175.850252       0.969       1.78220    10829.0
# 3      0.000    1.736952   170.307565       1.276       2.40641     8079.2
# 4      1.000    2.525592   171.595550       0.701       1.65450      603.3
#
#    koi_prad  koi_teq  koi_insol  koi_steff  koi_slogg  koi_srad         ra  \
# 0      2.26    793.0      93.59     5455.0      4.467     0.927  291.93423
# 1      2.83    443.0       9.11     5455.0      4.467     0.927  291.93423
# 2     14.60    638.0      39.30     5853.0      4.544     0.868  297.00482
# 3     33.46   1395.0     891.96     5805.0      4.564     0.791  285.53461
# 4      2.75   1406.0     926.16     6031.0      4.438     1.046  288.75488
#
#          dec  koi_kepmag  koi_disposition_CANDIDATE  \
# ...

# %%
# Exported this dataframe to be used with other models

# Now commented out so it doesn't continue to export it
# exoplanet_binary_encoded.to_csv('exoplanet_binary_encoded.csv', index=False)

# %%
# Delete koi_disposition column
exoplanet_numeric = exoplanet_complete.drop(['koi_disposition'], axis=1)
exoplanet_numeric.head()
# Out:
#    koi_score  koi_period  koi_time0bk  koi_impact  koi_duration  koi_depth  \
# 0      1.000    9.488036   170.538750       0.146       2.95750      615.8
# 1      0.969   54.418383   162.513840       0.586       4.50700      874.8
# 2      0.000   19.899140   175.850252       0.969       1.78220    10829.0
# 3      0.000    1.736952   170.307565       1.276       2.40641     8079.2
# 4      1.000    2.525592   171.595550       0.701       1.65450      603.3
#
#    koi_prad  koi_teq  koi_insol  koi_steff  koi_slogg  koi_srad         ra  \
# 0      2.26    793.0      93.59     5455.0      4.467     0.927  291.93423
# 1      2.83    443.0       9.11     5455.0      4.467     0.927  291.93423
# 2     14.60    638.0      39.30     5853.0      4.544     0.868  297.00482
# 3     33.46   1395.0     891.96     5805.0      4.564     0.791  285.53461
# 4      2.75   1406.0     926.16     6031.0      4.438     1.046  288.75488
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# ...

# %%
# Exported this dataframe to be used with other models

# Now commented out so it doesn't continue to export it
# exoplanet_numeric.to_csv('exoplanet_numeric.csv', index=False)
